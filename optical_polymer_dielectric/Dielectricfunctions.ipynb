# %%
import matplotlib.pyplot as plt
import matplotlib.axes as ax
import seaborn
import numpy as np
import pandas as pd
from IPython import display

# %%
realz1y0_zpol = np.loadtxt('z1_y0/zpol/epsilon_real.out')
imgz1y0_zpol =np.loadtxt('z1_y0/zpol/epsilon_img.out')
realz1y0_xpol = np.loadtxt('z1_y0/xpol/epsilon_real.out')
imgz1y0_xpol =np.loadtxt('z1_y0/xpol/epsilon_img.out')
realz1y0_ypol = np.loadtxt('z1_y0/ypol/epsilon_real.out')
imgz1y0_ypol =np.loadtxt('z1_y0/ypol/epsilon_img.out')

realz15y0_zpol = np.loadtxt('z1.5_y0/zpol/epsilon_real.out')
imgz15y0_zpol =np.loadtxt('z1.5_y0/zpol/epsilon_img.out')
realz15y0_xpol = np.loadtxt('z1.5_y0/xpol/epsilon_real.out')
imgz15y0_xpol =np.loadtxt('z1.5_y0/xpol/epsilon_img.out')
realz15y0_ypol = np.loadtxt('z1.5_y0/ypol/epsilon_real.out')
imgz15y0_ypol =np.loadtxt('z1.5_y0/ypol/epsilon_img.out')

realz25y0_zpol = np.loadtxt('z2.5_y0/zpol/epsilon_real.out')
imgz25y0_zpol =np.loadtxt('z2.5_y0/zpol/epsilon_img.out')
realz25y0_xpol = np.loadtxt('z2.5_y0/xpol/epsilon_real.out')
imgz25y0_xpol =np.loadtxt('z2.5_y0/xpol/epsilon_img.out')
realz25y0_ypol = np.loadtxt('z2.5_y0/ypol/epsilon_real.out')
imgz25y0_ypol =np.loadtxt('z2.5_y0/ypol/epsilon_img.out')
                            
realz35y0_zpol = np.loadtxt('z3.5_y0/zpol/epsilon_real.out')
imgz35y0_zpol =np.loadtxt('z3.5_y0/zpol/epsilon_img.out')
#realz35y0_xpol = np.loadtxt('z3.5_y0/xpol/epsilon_real.out')
#imgz35y0_xpol =np.loadtxt('z3.5_y0/xpol/epsilon_img.out')
realz35y0_ypol = np.loadtxt('z3.5_y0/ypol/epsilon_real.out')
imgz35y0_ypol =np.loadtxt('z3.5_y0/ypol/epsilon_img.out')                            
             
realz45y0_zpol = np.loadtxt('z4.5_y0/zpol/epsilon_real.out')
imgz45y0_zpol =np.loadtxt('z4.5_y0/zpol/epsilon_img.out')
realz45y0_xpol = np.loadtxt('z4.5_y0/xpol/epsilon_real.out')
imgz45y0_xpol =np.loadtxt('z4.5_y0/xpol/epsilon_img.out')
realz45y0_ypol = np.loadtxt('z4.5_y0/ypol/epsilon_real.out')
imgz45y0_ypol =np.loadtxt('z4.5_y0/ypol/epsilon_img.out')                            
                            
realz55y0_zpol = np.loadtxt('z5.5_y0/zpol/epsilon_real.out')
imgz55y0_zpol =np.loadtxt('z5.5_y0/zpol/epsilon_img.out')
realz55y0_xpol = np.loadtxt('z5.5_y0/xpol/epsilon_real.out')
imgz55y0_xpol =np.loadtxt('z5.5_y0/xpol/epsilon_img.out')
realz55y0_ypol = np.loadtxt('z5.5_y0/ypol/epsilon_real.out')
imgz55y0_ypol =np.loadtxt('z5.5_y0/ypol/epsilon_img.out')   

realz65y0_zpol = np.loadtxt('z6.5_y0/zpol/epsilon_real.out')
imgz65y0_zpol =np.loadtxt('z6.5_y0/zpol/epsilon_img.out')
realz65y0_xpol = np.loadtxt('z6.5_y0/xpol/epsilon_real.out')
imgz65y0_xpol =np.loadtxt('z6.5_y0/xpol/epsilon_img.out')
realz65y0_ypol = np.loadtxt('z6.5_y0/ypol/epsilon_real.out')
imgz65y0_ypol =np.loadtxt('z6.5_y0/ypol/epsilon_img.out')

# %%
realz15y3_zpol = np.loadtxt('z1.5_y3/zpol/epsilon_real.out')
imgz15y3_zpol =np.loadtxt('z1.5_y3/zpol/epsilon_img.out')
realz15y3_ypol = np.loadtxt('z1.5_y3/ypol/epsilon_real.out')
imgz15y3_ypol =np.loadtxt('z1.5_y3/ypol/epsilon_img.out')
            
realz35y3_zpol = np.loadtxt('z3.5_y3/zpol/epsilon_real.out')
imgz35y3_zpol =np.loadtxt('z3.5_y3/zpol/epsilon_img.out')
realz35y3_ypol = np.loadtxt('z3.5_y3/ypol/epsilon_real.out')
imgz35y3_ypol =np.loadtxt('z3.5_y3/ypol/epsilon_img.out')                            

realz65y3_zpol = np.loadtxt('z6.5_y3/zpol/epsilon_real.out')
imgz65y3_zpol =np.loadtxt('z6.5_y3/zpol/epsilon_img.out')
realz65y3_ypol = np.loadtxt('z6.5_y3/ypol/epsilon_real.out')
imgz65y3_ypol =np.loadtxt('z6.5_y3/ypol/epsilon_img.out')

# %%
realz15y6_zpol = np.loadtxt('z1.5_y6/zpol/epsilon_real.out')
imgz15y6_zpol =np.loadtxt('z1.5_y6/zpol/epsilon_img.out')
realz15y6_ypol = np.loadtxt('z1.5_y6/ypol/epsilon_real.out')
imgz15y6_ypol =np.loadtxt('z1.5_y6/ypol/epsilon_img.out')
            
realz35y6_zpol = np.loadtxt('z3.5_y6/zpol/epsilon_real.out')
imgz35y6_zpol =np.loadtxt('z3.5_y6/zpol/epsilon_img.out')
realz35y6_ypol = np.loadtxt('z3.5_y6/ypol/epsilon_real.out')
imgz35y6_ypol =np.loadtxt('z3.5_y6/ypol/epsilon_img.out')                            

realz65y6_zpol = np.loadtxt('z6.5_y6/zpol/epsilon_real.out')
imgz65y6_zpol =np.loadtxt('z6.5_y6/zpol/epsilon_img.out')
realz65y6_ypol = np.loadtxt('z6.5_y6/ypol/epsilon_real.out')
imgz65y6_ypol =np.loadtxt('z6.5_y6/ypol/epsilon_img.out')

# %%
realz6y9_zpol=np.loadtxt('z-6_y9/zpol/epsilon_real.out')
realz6y9_ypol=np.loadtxt('z-6_y9/ypol/epsilon_real.out')
realz6y12_zpol=np.loadtxt('z-6_y12/zpol/epsilon_real.out')
realz6y12_ypol=np.loadtxt('z-6_y12/ypol/epsilon_real.out')
realz6y14_zpol=np.loadtxt('z-6_y14/zpol/epsilon_real.out')
realz6y14_ypol=np.loadtxt('z-6_y14/ypol/epsilon_real.out')

# %%
imgz6y9_zpol=np.loadtxt('z-6_y9/zpol/epsilon_img.out')
imgz6y9_ypol=np.loadtxt('z-6_y9/ypol/epsilon_img.out')
imgz6y12_zpol=np.loadtxt('z-6_y12/zpol/epsilon_img.out')
imgz6y12_ypol=np.loadtxt('z-6_y12/ypol/epsilon_img.out')
imgz6y14_zpol=np.loadtxt('z-6_y14/zpol/epsilon_img.out')
imgz6y14_ypol=np.loadtxt('z-6_y14/ypol/epsilon_img.out')

# %%
fig, axes= plt.subplots(nrows=2, ncols=3, figsize=(12,8), layout='tight')


plt.suptitle('X-direction Polarization   Across Z-distances 1-6.5 at Y=0')

plt.subplot(2,3,1)
plt.title('z=1')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.xlim(0,5)
plt.ylim(0,8)
plt.xticks(ticks=[1,2,3,4,5])
plt.plot(realz1y0_xpol[:,0],realz1y0_xpol[:,1], label= '$\epsilon_1$', color='blue',linestyle = 'dashed')
plt.plot(imgz1y0_xpol[:,0],imgz1y0_xpol[:,1], label= '$\epsilon_2$', color='orange',linewidth='2')
plt.legend(fontsize="12", loc='upper left')


plt.subplot(2,3,2)
plt.title('z=1.5')
plt.xlim(0,5)
plt.ylim(0,8)
plt.xticks(ticks=[1,2,3,4,5])

plt.plot(realz15y0_xpol[:,0],realz15y0_xpol[:,1], label= '$\epsilon_1$', color='blue',linestyle = 'dashed')
plt.plot(imgz15y0_xpol[:,0],imgz15y0_xpol[:,1], label= '$\epsilon_2$', color='orange',linewidth='2')

plt.subplot(2,3,3)
plt.title('z=2.5')
plt.xlim(0,5)
plt.ylim(0,8)
plt.xticks(ticks=[1,2,3,4,5])
plt.plot(realz25y0_xpol[:,0],realz25y0_xpol[:,1], label= '$\epsilon_1$', color='blue',linestyle = 'dashed')
plt.plot(imgz25y0_xpol[:,0],imgz25y0_xpol[:,1], label= '$\epsilon_2$', color='orange',linewidth='2')

plt.subplot(2,3,4)
plt.title('z=4.5')
plt.xlim(0,5)
plt.ylim(0,8)
plt.xticks(ticks=[1,2,3,4,5])
plt.xlabel('Frequency $\omega$ (eV)')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.plot(realz45y0_xpol[:,0],realz45y0_xpol[:,1], label= '$\epsilon_1$', color='blue',linestyle = 'dashed')
plt.plot(imgz45y0_xpol[:,0],imgz45y0_xpol[:,1], label= '$\epsilon_2$', color='orange',linewidth='2')

plt.subplot(2,3,5)
plt.title('z=5.5')
plt.xlim(0,5)
plt.ylim(0,8)
plt.xticks(ticks=[1,2,3,4,5])
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(realz55y0_xpol[:,0],realz55y0_xpol[:,1], label= '$\epsilon_1$', color='blue',linestyle = 'dashed')
plt.plot(imgz55y0_xpol[:,0],imgz55y0_xpol[:,1], label= '$\epsilon_2$', color='orange',linewidth='2')

plt.subplot(2,3,6)
plt.title('z=6.5')
plt.xlim(0,5)
plt.ylim(0,8)
plt.xticks(ticks=[1,2,3,4,5])
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(realz65y0_xpol[:,0],realz65y0_xpol[:,1], label= '$\epsilon_1$', color = "blue",linestyle = 'dashed')
plt.plot(imgz65y0_xpol[:,0],imgz65y0_xpol[:,1], label= '$\epsilon_2$', color='orange',linewidth='2')

plt.tight_layout(pad=1)
#plt.savefig('plots/xpol_z1-65_y0_v2.pdf',bbox_inches='tight')

# %%
fig, axes= plt.subplots(nrows=2, ncols=3, figsize=(12,6), layout='tight')


plt.suptitle('Y-direction Polarization   Across Z-distances 1-6.5 at Y=0')

plt.subplot(2,3,1)
plt.title('z=1')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.xlim(0,5)
plt.ylim(-1,10)
plt.xticks(ticks=[1,2,3,4,5])
plt.plot(realz1y0_ypol[:,0],realz1y0_ypol[:,1], label= '$\epsilon_1$', color='blue', linewidth='2')
plt.plot(imgz1y0_ypol[:,0],imgz1y0_ypol[:,1], label= '$\epsilon_2$',linestyle = 'dashed', color='orange')
plt.legend(fontsize="12", loc='upper left')


plt.subplot(2,3,2)
plt.title('z=1.5')
plt.xlim(0,5)
plt.ylim(-1,10)
plt.xticks(ticks=[1,2,3,4,5])

plt.plot(realz15y0_ypol[:,0],realz15y0_ypol[:,1], label= '$\epsilon_1$', color='blue', linewidth='2')
plt.plot(imgz15y0_ypol[:,0],imgz15y0_ypol[:,1], label= '$\epsilon_2$', linestyle = 'dashed',color='orange')

plt.subplot(2,3,3)
plt.title('z=2.5')
plt.xlim(0,5)
plt.ylim(-1,10)
plt.xticks(ticks=[1,2,3,4,5])
plt.plot(realz25y0_ypol[:,0],realz25y0_ypol[:,1], label= '$\epsilon_1$', color='blue', linewidth='2')
plt.plot(imgz25y0_ypol[:,0],imgz25y0_ypol[:,1], label= '$\epsilon_2$',linestyle = 'dashed', color='orange')

plt.subplot(2,3,4)
plt.title('z=4.5')
plt.xlim(0,5)
plt.ylim(-1,10)
plt.xticks(ticks=[1,2,3,4,5])
plt.xlabel('Frequency $\omega$ (eV)')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.plot(realz45y0_ypol[:,0],realz45y0_ypol[:,1], label= '$\epsilon_1$', color='blue', linewidth='2')
plt.plot(imgz45y0_ypol[:,0],imgz45y0_ypol[:,1], label= '$\epsilon_2$',linestyle = 'dashed', color='orange')

plt.subplot(2,3,5)
plt.title('z=5.5')
plt.xlim(0,5)
plt.ylim(-1,10)
plt.xticks(ticks=[1,2,3,4,5])
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(realz55y0_ypol[:,0],realz55y0_ypol[:,1], label= '$\epsilon_1$', color='blue', linewidth='2')
plt.plot(imgz55y0_ypol[:,0],imgz55y0_ypol[:,1], label= '$\epsilon_2$',linestyle = 'dashed', color='orange')

plt.subplot(2,3,6)
plt.title('z=6.5')
plt.xlim(0,5)
plt.ylim(-1,10)
plt.xticks(ticks=[1,2,3,4,5])
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(realz65y0_ypol[:,0],realz65y0_ypol[:,1], label= '$\epsilon_1$', color = "blue",  linewidth='2')
plt.plot(imgz65y0_ypol[:,0],imgz65y0_ypol[:,1], label= '$\epsilon_2$',linestyle = 'dashed', color='orange')

plt.tight_layout(pad=1)

# %%
fig, axes= plt.subplots(nrows=2, ncols=3, figsize=(12,8), layout='tight')


plt.suptitle('y-direction Polarization   Across Z-distances 1-6.5 at Y=0')

plt.subplot(2,3,1)
plt.title('z=1.5')
plt.xlim(0,5)
plt.ylim(-1,10)
plt.xticks(ticks=[1,2,3,4,5])

plt.plot(realz15y0_zpol[:,0],realz15y0_zpol[:,1], label= '$\epsilon_1$', color='blue', linewidth='2')
plt.plot(imgz15y0_zpol[:,0],imgz15y0_zpol[:,1], label= '$\epsilon_2$', linestyle = 'dashed',color='orange')

plt.subplot(2,3,2)
plt.title('z=2.5')
plt.xlim(0,5)
plt.ylim(-1,10)
plt.xticks(ticks=[1,2,3,4,5])
plt.plot(realz25y0_zpol[:,0],realz25y0_zpol[:,1], label= '$\epsilon_1$', color='blue', linewidth='2')
plt.plot(imgz25y0_zpol[:,0],imgz25y0_zpol[:,1], label= '$\epsilon_2$',linestyle = 'dashed', color='orange')

plt.subplot(2,3,3)
plt.title('z=3.5')
plt.xlim(0,5)
plt.ylim(-1,10)
plt.xticks(ticks=[1,2,3,4,5])
plt.plot(realz35y0_zpol[:,0],realz35y0_zpol[:,1], label= '$\epsilon_1$', color='blue', linewidth='2')
plt.plot(imgz35y0_zpol[:,0],imgz35y0_zpol[:,1], label= '$\epsilon_2$',linestyle = 'dashed', color='orange')


plt.subplot(2,3,4)
plt.title('z=4.5')
plt.xlim(0,5)
plt.ylim(-1,10)
plt.xticks(ticks=[1,2,3,4,5])
plt.xlabel('Frequency $\omega$ (eV)')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.plot(realz45y0_zpol[:,0],realz45y0_zpol[:,1], label= '$\epsilon_1$', color='blue', linewidth='2')
plt.plot(imgz45y0_zpol[:,0],imgz45y0_zpol[:,1], label= '$\epsilon_2$',linestyle = 'dashed', color='orange')

plt.subplot(2,3,5)
plt.title('z=5.5')
plt.xlim(0,5)
plt.ylim(-1,10)
plt.xticks(ticks=[1,2,3,4,5])
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(realz55y0_zpol[:,0],realz55y0_zpol[:,1], label= '$\epsilon_1$', color='blue', linewidth='2')
plt.plot(imgz55y0_zpol[:,0],imgz55y0_zpol[:,1], label= '$\epsilon_2$',linestyle = 'dashed', color='orange')

plt.subplot(2,3,6)
plt.title('z=6.5')
plt.xlim(0,5)
plt.ylim(-1,10)
plt.xticks(ticks=[1,2,3,4,5])
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(realz65y0_zpol[:,0],realz65y0_zpol[:,1], label= '$\epsilon_1$', color = "blue",  linewidth='2')
plt.plot(imgz65y0_zpol[:,0],imgz65y0_zpol[:,1], label= '$\epsilon_2$',linestyle = 'dashed', color='orange')

plt.tight_layout(pad=1)

# %%
fig, axes= plt.subplots(nrows=2, ncols=3,  dpi=600, layout='tight')
#plt.xlim(-0.2,6)
#plt.ylim(-0.2,18)
#plt.xticks(ticks=[1,2,3,4,5,6])

plt.suptitle('Z-direction Polarization   Across Z-distances 1-6.5 at Y=0')  

plt.subplot(2,3,1)
plt.title('z=1')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.xlim(-0.2,6)
plt.ylim(-0.2,18)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.plot(realz1y0_zpol[:,0],realz1y0_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz1y0_zpol[:,0],imgz1y0_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(2,3,2)
plt.title('z=1.5')
plt.xlim(-0.2,6)
plt.ylim(-0.2,18)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.plot(realz15y0_zpol[:,0],realz15y0_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz15y0_zpol[:,0],imgz15y0_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(2,3,3)
plt.title('z=2.5')
plt.xlim(-0.2,6)
plt.ylim(-0.2,18)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.plot(realz25y0_zpol[:,0],realz25y0_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz25y0_zpol[:,0],imgz25y0_zpol[:,1], label= '$\epsilon_2$')
plt.legend(fontsize="7")

plt.subplot(2,3,4)
plt.title('z=4.5')
plt.xlim(-0.2,6)
plt.ylim(-0.2,18)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.xlabel('Frequency $\omega$ (eV)')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.plot(realz45y0_zpol[:,0],realz45y0_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz45y0_zpol[:,0],imgz45y0_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(2,3,5)
plt.title('z=5.5')
plt.xlim(-0.2,6)
plt.ylim(-0.2,18)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(realz55y0_zpol[:,0],realz55y0_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz55y0_zpol[:,0],imgz55y0_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(2,3,6)
plt.title('z=6.5')
plt.xlim(-0.2,6)
plt.ylim(-0.2,18)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(realz65y0_zpol[:,0],realz65y0_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y0_zpol[:,0],imgz65y0_zpol[:,1], label= '$\epsilon_2$')

plt.show()

# %%
plt.figure( dpi=600, layout='tight')
plt.subplots(nrows=2, ncols=3, sharex='all', sharey='all')
plt.xlim(0,6)
plt.ylim(0,8)

plt.suptitle('Z-direction Polarization  Across Z-distances 1-6.5 at Y=0')

plt.subplot(2,3,1)
plt.title('z=1')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.plot(realz15y0_ypol[:,0],realz1y0_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz1y0_ypol[:,0],imgz1y0_ypol[:,1], label= '$\epsilon_2$')

plt.subplot(2,3,2)
plt.title('z=1.5')
plt.plot(realz15y0_ypol[:,0],realz15y0_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz15y0_ypol[:,0],imgz15y0_ypol[:,1], label= '$\epsilon_2$')

plt.subplot(2,3,3)
plt.title('z=2.5')
plt.plot(realz25y0_ypol[:,0],realz25y0_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz25y0_ypol[:,0],imgz25y0_ypol[:,1], label= '$\epsilon_2$')
plt.legend(fontsize="7")

plt.subplot(2,3,4)
plt.title('z=4.5')
plt.xlabel('Frequency $\omega$ (eV)')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.plot(realz45y0_ypol[:,0],realz45y0_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz45y0_ypol[:,0],imgz45y0_ypol[:,1], label= '$\epsilon_2$')

plt.subplot(2,3,5)
plt.title('z=5.5')
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(realz55y0_ypol[:,0],realz55y0_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz55y0_ypol[:,0],imgz55y0_ypol[:,1], label= '$\epsilon_2$')

plt.subplot(2,3,6)
plt.title('z=6.5')
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(realz65y0_ypol[:,0],realz65y0_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y0_ypol[:,0],imgz65y0_ypol[:,1], label= '$\epsilon_2$')

plt.show()

# %%
plt.subplots(2,3, sharex='all', sharey='all', figsize=(10,8), layout='tight')
plt.xlim(0,6)
plt.ylim(0,8)

plt.suptitle('Z-direction Polarization  Across Z-distances 1-6.5 at Y=3',fontsize='20')

plt.subplot(231)
plt.title('z=1.5', fontsize='16')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
plt.plot(realz15y3_zpol[:,0],realz15y3_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz15y3_zpol[:,0],imgz15y3_zpol[:,1], label= '$\epsilon_2$')
plt.legend(fontsize="12", loc='upper left')

plt.subplot(232)
plt.title('z=3.5', fontsize='16')
plt.plot(realz35y3_zpol[:,0],realz35y3_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz35y3_zpol[:,0],imgz35y3_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(233)
plt.title('z=6.5', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(realz65y3_zpol[:,0],realz65y3_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y3_zpol[:,0],imgz65y3_zpol[:,1], label= '$\epsilon_2$')


plt.suptitle('Z-direction Polarization  Across Z-distances 1-6.5 at Y=6')

plt.subplot(234)
plt.title('z=1.5', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
plt.plot(realz15y6_zpol[:,0],realz15y6_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz15y6_zpol[:,0],imgz15y6_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(235)
plt.title('z=3.5', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(realz35y6_zpol[:,0],realz35y6_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz35y6_zpol[:,0],imgz35y6_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(236)
plt.title('z=6.5', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(realz65y6_zpol[:,0],realz65y6_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y6_zpol[:,0],imgz65y6_zpol[:,1], label= '$\epsilon_2$')
#plt.legend(fontsize="12", loc='upper left')

plt.show()

# %%
fig, ax = plt.subplots(1,3, sharex='all', sharey='all')
plt.xlim(0,6)
plt.ylim(0,8)

plt.suptitle('Z-direction Polarization  Across Z-distances 1-6.5 at Y=6')

plt.subplot(1,3,1)
plt.title('z=1.5')
plt.xlabel('Frequency $\omega$ (eV)')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.plot(realz15y6_zpol[:,0],realz15y6_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz15y6_zpol[:,0],imgz15y6_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(1,3,2)
plt.title('z=3.5')
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(realz35y6_zpol[:,0],realz35y6_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz35y6_zpol[:,0],imgz35y6_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(1,3,3)
plt.title('z=6.5')
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(realz65y6_zpol[:,0],realz65y6_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y6_zpol[:,0],imgz65y6_zpol[:,1], label= '$\epsilon_2$')
plt.legend(fontsize="7")

plt.show()

# %%
plt.subplots(3,3, sharex='all', sharey='all', figsize=(12,13), layout='tight')
plt.xlim(0,6)
plt.ylim(0,8)

plt.suptitle('Z-direction Polarization $\epsilon_2$',fontsize='20')

plt.subplot(331)
plt.title('z=1.5, y=0', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
#plt.plot(realz15y0_zpol[:,0],realz15y0_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz15y0_zpol[:,0],imgz15y0_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(332)
plt.title('z=3.5, y=0', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(realz35y0_zpol[:,0],realz35y0_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz35y0_zpol[:,0],imgz35y0_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(333)
plt.title('z=6.5, y=0', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(realz65y0_zpol[:,0],realz65y0_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y0_zpol[:,0],imgz65y0_zpol[:,1], label= '$\epsilon_2$')
plt.legend(fontsize="12")


plt.subplot(334)
plt.title('z=1.5, y=3', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
#plt.plot(realz15y3_zpol[:,0],realz15y3_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz15y3_zpol[:,0],imgz15y3_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(335)
plt.title('z=3.5, y=3', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(realz35y3_zpol[:,0],realz35y3_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz35y3_zpol[:,0],imgz35y3_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(336)
plt.title('z=6.5, y=3', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(realz65y3_zpol[:,0],realz65y3_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y3_zpol[:,0],imgz65y3_zpol[:,1], label= '$\epsilon_2$')
plt.legend(fontsize="12")


plt.subplot(337)
plt.title('z=1.5, y=6', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
#plt.plot(realz15y6_zpol[:,0],realz15y6_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz15y6_zpol[:,0],imgz15y6_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(338)
plt.title('z=3.5, y=6', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(realz35y6_zpol[:,0],realz35y6_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz35y6_zpol[:,0],imgz35y6_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(339)
plt.title('z=6.5, y=6', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(realz65y6_zpol[:,0],realz65y6_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y6_zpol[:,0],imgz65y6_zpol[:,1], label= '$\epsilon_2$')
plt.legend(fontsize="12")

plt.show()

# %%
plt.subplots(3,3, sharex='all', sharey='all', figsize=(12,13), layout='tight')
#plt.xlim(0,100)
plt.ylim(0,5)

plt.suptitle('Y-direction Polarization',fontsize='20')

plt.subplot(331)
plt.title('z=1.5, y=0', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
plt.plot(realz15y0_ypol[:,0],realz15y0_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz15y0_ypol[:,0],imgz15y0_ypol[:,1], label= '$\epsilon_2$')

plt.subplot(332)
plt.title('z=3.5, y=0', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(realz35y0_ypol[:,0],realz35y0_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz35y0_ypol[:,0],imgz35y0_ypol[:,1], label= '$\epsilon_2$')

plt.subplot(333)
plt.title('z=6.5, y=0', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(realz65y0_ypol[:,0],realz65y0_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y0_ypol[:,0],imgz65y0_ypol[:,1], label= '$\epsilon_2$')
plt.legend(fontsize="12")


plt.subplot(334)
plt.title('z=1.5, y=3', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
plt.plot(realz15y3_ypol[:,0],realz15y3_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz15y3_ypol[:,0],imgz15y3_ypol[:,1], label= '$\epsilon_2$')

plt.subplot(335)
plt.title('z=3.5, y=3', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(realz35y3_ypol[:,0],realz35y3_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz35y3_ypol[:,0],imgz35y3_ypol[:,1], label= '$\epsilon_2$')

plt.subplot(336)
plt.title('z=6.5, y=3', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(realz65y3_ypol[:,0],realz65y3_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y3_ypol[:,0],imgz65y3_ypol[:,1], label= '$\epsilon_2$')
plt.legend(fontsize="12")


plt.subplot(337)
plt.title('z=1.5, y=6', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
plt.plot(realz15y6_ypol[:,0],realz15y6_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz15y6_ypol[:,0],imgz15y6_ypol[:,1], label= '$\epsilon_2$')

plt.subplot(338)
plt.title('z=3.5, y=6', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(realz35y6_ypol[:,0],realz35y6_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz35y6_ypol[:,0],imgz35y6_ypol[:,1], label= '$\epsilon_2$')

plt.subplot(339)
plt.title('z=6.5, y=6', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(realz65y6_ypol[:,0],realz65y6_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y6_ypol[:,0],imgz65y6_ypol[:,1], label= '$\epsilon_2$')
plt.legend(fontsize="12")

plt.show()

# %%
plt.subplots(2,3, sharex='all', sharey='all', figsize=(12,8),layout='tight')
plt.xlim(0,6)
plt.ylim(0,8)

plt.suptitle('Y-direction Polarization at Z=6', fontsize='20')

plt.subplot(231)
plt.title(' y=0', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
plt.plot(realz65y0_ypol[:,0],realz65y0_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y0_ypol[:,0],imgz65y0_ypol[:,1], label= '$\epsilon_2$')
plt.legend(fontsize="12", loc='upper left')

plt.subplot(232)
plt.title('y=3', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(realz65y3_ypol[:,0],realz65y3_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y3_ypol[:,0],imgz65y3_ypol[:,1], label= '$\epsilon_2$')

plt.subplot(233)
plt.title('y=6', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(realz65y6_ypol[:,0],realz65y6_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y6_ypol[:,0],imgz65y6_ypol[:,1], label= '$\epsilon_2$')


plt.subplot(234)
plt.title('y=9', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
plt.plot(realz6y9_ypol[:,0],realz6y9_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz6y9_ypol[:,0],imgz6y9_ypol[:,1], label= '$\epsilon_2$')

plt.subplot(235)
plt.title('y=12', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(realz6y9_ypol[:,0],realz6y9_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz6y9_ypol[:,0],imgz6y9_ypol[:,1], label= '$\epsilon_2$')

plt.subplot(236)
plt.title('y=14', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(realz6y9_ypol[:,0],realz6y9_ypol[:,1], label= '$\epsilon_1$')
plt.plot(imgz6y9_ypol[:,0],imgz6y9_ypol[:,1], label= '$\epsilon_2$')
#plt.legend(fontsize="12")


#plt.show()
#plt.savefig('plots/ypol_z6_y0-14.png',bbox_inches='tight')
#plt.savefig('plots/ypol_z6_y0-14.pdf',bbox_inches='tight')

# %%
plt.subplots(6,1, sharex='all', figsize=(6,16),sharey='all',layout='tight')
plt.xlim(0,5)
plt.ylim(0,8)

plt.suptitle('Z-direction $\epsilon_2$ at Z=6 Across Y=0-14 ', fontsize='16')

plt.subplot(611)
#plt.title(' y=0', fontsize='16')
#plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
#plt.plot(realz65y0_zpol[:,0],realz65y0_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y0_zpol[:,0],imgz65y0_zpol[:,1], label= 'y=0' , color='red')
plt.legend(fontsize="12", loc='upper right')

plt.subplot(612)
#plt.title('y=3', fontsize='16')
#plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(realz65y3_zpol[:,0],realz65y3_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y3_zpol[:,0],imgz65y3_zpol[:,1], label= 'y=3' , color='red')
plt.legend(fontsize="12", loc='upper right')

plt.subplot(613)
#plt.title('y=6', fontsize='16')
#plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(realz65y6_zpol[:,0],realz65y6_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz65y6_zpol[:,0],imgz65y6_zpol[:,1], label= 'y=6' , color='red')
plt.legend(fontsize="12", loc='upper right')


plt.subplot(614)
#plt.title('y=9', fontsize='16')
#plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
#plt.plot(realz6y9_zpol[:,0],realz6y9_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz6y9_zpol[:,0],imgz6y9_zpol[:,1], label= 'y=9' , color='red')
plt.legend(fontsize="12", loc='upper right')

plt.subplot(615)
#plt.title('y=12', fontsize='16')
#plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(realz6y9_zpol[:,0],realz6y9_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz6y9_zpol[:,0],imgz6y9_zpol[:,1], label= 'y=12' , color='red')
plt.legend(fontsize="12", loc='upper right')

plt.subplot(616)
#plt.title('y=14', fontsize='16')
#plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(realz6y9_zpol[:,0],realz6y9_zpol[:,1], label= '$\epsilon_1$')
plt.plot(imgz6y9_zpol[:,0],imgz6y9_zpol[:,1], label= 'y=14' , color='red')
plt.legend(fontsize="12", loc='upper right')


plt.show()
#plt.savefig('plots/e2_zpol_z6_stack.png',bbox_inches='tight')
