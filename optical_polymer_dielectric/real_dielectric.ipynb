# %%
import matplotlib.pyplot as plt
import matplotlib.axes as ax
import seaborn
import numpy as np
import pandas as pd
from IPython import display

# %%
realz1y0_zpol = np.loadtxt('z1_y0/zpol/epsilon_real.out')
imagz1y0_zpol =np.loadtxt('z1_y0/zpol/epsilon_img.out')
realz1y0_xpol = np.loadtxt('z1_y0/xpol/epsilon_real.out')
imagz1y0_xpol =np.loadtxt('z1_y0/xpol/epsilon_img.out')
realz1y0_ypol = np.loadtxt('z1_y0/ypol/epsilon_real.out')
imagz1y0_ypol =np.loadtxt('z1_y0/ypol/epsilon_img.out')

realz15y0_zpol = np.loadtxt('z1.5_y0/zpol/epsilon_real.out')
imagz15y0_zpol =np.loadtxt('z1.5_y0/zpol/epsilon_img.out')
realz15y0_xpol = np.loadtxt('z1.5_y0/xpol/epsilon_real.out')
imagz15y0_xpol =np.loadtxt('z1.5_y0/xpol/epsilon_img.out')
realz15y0_ypol = np.loadtxt('z1.5_y0/ypol/epsilon_real.out')
imagz15y0_ypol =np.loadtxt('z1.5_y0/ypol/epsilon_img.out')

realz25y0_zpol = np.loadtxt('z2.5_y0/zpol/epsilon_real.out')
imagz25y0_zpol =np.loadtxt('z2.5_y0/zpol/epsilon_img.out')
realz25y0_xpol = np.loadtxt('z2.5_y0/xpol/epsilon_real.out')
imagz25y0_xpol =np.loadtxt('z2.5_y0/xpol/epsilon_img.out')
realz25y0_ypol = np.loadtxt('z2.5_y0/ypol/epsilon_real.out')
imagz25y0_ypol =np.loadtxt('z2.5_y0/ypol/epsilon_img.out')
                            
realz35y0_zpol = np.loadtxt('z3.5_y0/zpol/epsilon_real.out')
imagz35y0_zpol =np.loadtxt('z3.5_y0/zpol/epsilon_img.out')
#realz35y0_xpol = np.loadtxt('z3.5_y0/xpol/epsilon_real.out')
#imagz35y0_xpol =np.loadtxt('z3.5_y0/xpol/epsilon_img.out')
realz35y0_ypol = np.loadtxt('z3.5_y0/ypol/epsilon_real.out')
imagz35y0_ypol =np.loadtxt('z3.5_y0/ypol/epsilon_img.out')                            
             
realz45y0_zpol = np.loadtxt('z4.5_y0/zpol/epsilon_real.out')
imagz45y0_zpol =np.loadtxt('z4.5_y0/zpol/epsilon_img.out')
realz45y0_xpol = np.loadtxt('z4.5_y0/xpol/epsilon_real.out')
imagz45y0_xpol =np.loadtxt('z4.5_y0/xpol/epsilon_img.out')
realz45y0_ypol = np.loadtxt('z4.5_y0/ypol/epsilon_real.out')
imagz45y0_ypol =np.loadtxt('z4.5_y0/ypol/epsilon_img.out')                            
                            
realz55y0_zpol = np.loadtxt('z5.5_y0/zpol/epsilon_real.out')
imagz55y0_zpol =np.loadtxt('z5.5_y0/zpol/epsilon_img.out')
realz55y0_xpol = np.loadtxt('z5.5_y0/xpol/epsilon_real.out')
imagz55y0_xpol =np.loadtxt('z5.5_y0/xpol/epsilon_img.out')
realz55y0_ypol = np.loadtxt('z5.5_y0/ypol/epsilon_real.out')
imagz55y0_ypol =np.loadtxt('z5.5_y0/ypol/epsilon_img.out')   

realz65y0_zpol = np.loadtxt('z6.5_y0/zpol/epsilon_real.out')
imagz65y0_zpol =np.loadtxt('z6.5_y0/zpol/epsilon_img.out')
realz65y0_xpol = np.loadtxt('z6.5_y0/xpol/epsilon_real.out')
imagz65y0_xpol =np.loadtxt('z6.5_y0/xpol/epsilon_img.out')
realz65y0_ypol = np.loadtxt('z6.5_y0/ypol/epsilon_real.out')
imagz65y0_ypol =np.loadtxt('z6.5_y0/ypol/epsilon_img.out')

# %%
realz15y3_zpol = np.loadtxt('z1.5_y3/zpol/epsilon_real.out')
imagz15y3_zpol =np.loadtxt('z1.5_y3/zpol/epsilon_img.out')
realz15y3_ypol = np.loadtxt('z1.5_y3/ypol/epsilon_real.out')
imagz15y3_ypol =np.loadtxt('z1.5_y3/ypol/epsilon_img.out')
            
realz35y3_zpol = np.loadtxt('z3.5_y3/zpol/epsilon_real.out')
imagz35y3_zpol =np.loadtxt('z3.5_y3/zpol/epsilon_img.out')
realz35y3_ypol = np.loadtxt('z3.5_y3/ypol/epsilon_real.out')
imagz35y3_ypol =np.loadtxt('z3.5_y3/ypol/epsilon_img.out')                            

realz65y3_zpol = np.loadtxt('z6.5_y3/zpol/epsilon_real.out')
imagz65y3_zpol =np.loadtxt('z6.5_y3/zpol/epsilon_img.out')
realz65y3_ypol = np.loadtxt('z6.5_y3/ypol/epsilon_real.out')
imagz65y3_ypol =np.loadtxt('z6.5_y3/ypol/epsilon_img.out')

# %%
realz15y6_zpol = np.loadtxt('z1.5_y6/zpol/epsilon_real.out')
imagz15y6_zpol =np.loadtxt('z1.5_y6/zpol/epsilon_img.out')
realz15y6_ypol = np.loadtxt('z1.5_y6/ypol/epsilon_real.out')
imagz15y6_ypol =np.loadtxt('z1.5_y6/ypol/epsilon_img.out')
            
realz35y6_zpol = np.loadtxt('z3.5_y6/zpol/epsilon_real.out')
imagz35y6_zpol =np.loadtxt('z3.5_y6/zpol/epsilon_img.out')
realz35y6_ypol = np.loadtxt('z3.5_y6/ypol/epsilon_real.out')
imagz35y6_ypol =np.loadtxt('z3.5_y6/ypol/epsilon_img.out')                            

realz65y6_zpol = np.loadtxt('z6.5_y6/zpol/epsilon_real.out')
imagz65y6_zpol =np.loadtxt('z6.5_y6/zpol/epsilon_img.out')
realz65y6_ypol = np.loadtxt('z6.5_y6/ypol/epsilon_real.out')
imagz65y6_ypol =np.loadtxt('z6.5_y6/ypol/epsilon_img.out')

# %%
fig, axes= plt.subplots(nrows=2, ncols=3,  dpi=600, layout='tight')
#plt.xlim(0,6)
#plt.ylim(0,10)
#plt.xticks(ticks=[1,2,3,4,5,6])

plt.suptitle(' Real Dielectric ($\epsilon_1$) Across Z-distances 1-6.5 at Y=0')  

plt.subplot(2,3,1)
plt.title('z=1')
plt.ylabel('$\epsilon_1 (\omega) $')
plt.xlim(0,6)
plt.ylim(0,10)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.plot(realz1y0_zpol[:,0],realz1y0_zpol[:,1], label= 'zpol', color="#4682b4")
plt.plot(realz1y0_xpol[:,0],realz1y0_xpol[:,1], label= 'xpol', color="#b4af46")
plt.plot(realz1y0_ypol[:,0],realz1y0_ypol[:,1], label= 'ypol', color="#b4464b")

plt.subplot(2,3,2)
plt.title('z=1.5')
plt.xlim(0,6)
plt.ylim(0,10)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.plot(realz15y0_zpol[:,0],realz15y0_zpol[:,1], label= 'zpol', color="#4682b4")
plt.plot(realz15y0_xpol[:,0],realz15y0_xpol[:,1], label= 'xpol', color="#b4af46")
plt.plot(realz15y0_ypol[:,0],realz15y0_ypol[:,1], label= 'ypol', color="#b4464b")

plt.subplot(2,3,3)
plt.title('z=2.5')
plt.xlim(0,6)
plt.ylim(0,10)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.plot(realz25y0_zpol[:,0],realz25y0_zpol[:,1], label= 'zpol', color="#4682b4")
plt.plot(realz25y0_xpol[:,0],realz25y0_xpol[:,1], label= 'xpol', color="#b4af46")
plt.plot(realz25y0_ypol[:,0],realz25y0_ypol[:,1], label= 'ypol', color="#b4464b")
plt.legend(fontsize="7")


plt.subplot(2,3,4)
plt.title('z=4.5')
plt.xlim(0,6)
plt.ylim(0,10)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.xlabel(' $\omega$ (eV)')
plt.ylabel('$\epsilon_1 (\omega) $')
plt.plot(realz45y0_zpol[:,0],realz45y0_zpol[:,1], label= 'zpol', color="#4682b4")
plt.plot(realz45y0_xpol[:,0],realz45y0_xpol[:,1], label= 'xpol', color="#b4af46")
plt.plot(realz45y0_ypol[:,0],realz45y0_ypol[:,1], label= 'ypol', color="#b4464b")


plt.subplot(2,3,5)
plt.title('z=5.5')
plt.xlim(0,6)
plt.ylim(0,10)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.xlabel(' $\omega$ (eV)')
plt.plot(realz55y0_zpol[:,0],realz55y0_zpol[:,1], label= 'zpol', color="#4682b4")
plt.plot(realz55y0_xpol[:,0],realz55y0_xpol[:,1], label= 'xpol', color="#b4af46")
plt.plot(realz55y0_ypol[:,0],realz55y0_ypol[:,1], label= 'ypol', color="#b4464b")

plt.subplot(2,3,6)
plt.title('z=6.5')
plt.xlim(0,6)
plt.ylim(0,10)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.xlabel(' $\omega$ (eV)')
plt.plot(realz65y0_zpol[:,0],realz65y0_zpol[:,1], label= 'zpol', color="#4682b4")
plt.plot(realz65y0_xpol[:,0],realz65y0_xpol[:,1], label= 'xpol', color="#b4af46")
plt.plot(realz65y0_ypol[:,0],realz65y0_ypol[:,1], label= 'ypol', color="#b4464b")

plt.show()

# %%
fid,axes = plt.subplots(3,3, figsize=(12,13), layout='tight')

plt.suptitle('Real Dielectric ($\epsilon_1$) Across Z=1-6.5 and Y=0-6',fontsize='20')

plt.subplot(331)
plt.title('z=1.5, y=0', fontsize='16')
plt.xlim(0,6)
plt.ylim(0,10)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
plt.plot(realz15y0_ypol[:,0],realz15y0_ypol[:,1], label= 'ypol', color="#b4464b")
plt.plot(realz15y0_zpol[:,0],realz15y0_zpol[:,1], label= 'zpol', color="#4682b4")
plt.legend(fontsize="16", loc='upper left')

plt.subplot(332)
plt.title('z=3.5, y=0', fontsize='16')
plt.xlim(0,6)
plt.ylim(0,10)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.plot(realz35y0_ypol[:,0],realz35y0_ypol[:,1], label= 'ypol', color="#b4464b")
plt.plot(realz35y0_zpol[:,0],realz35y0_zpol[:,1], label= 'zpol', color="#4682b4")

plt.subplot(333)
plt.title('z=6.5, y=0', fontsize='16')
plt.xlim(0,6)
plt.ylim(0,10)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.plot(realz65y0_ypol[:,0],realz65y0_ypol[:,1], label= 'ypol', color="#b4464b")
plt.plot(realz65y0_zpol[:,0],realz65y0_zpol[:,1], label= 'zpol', color="#4682b4")
#plt.legend(fontsize="16")

plt.subplot(334)
plt.title('z=1.5, y=3', fontsize='16')
plt.xlim(0,6)
plt.ylim(0,10)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
plt.plot(realz15y3_ypol[:,0],realz15y3_ypol[:,1], label= 'ypol', color="#b4464b")
plt.plot(realz15y3_zpol[:,0],realz15y3_zpol[:,1], label= 'zpol', color="#4682b4")
plt.legend(fontsize="16", loc='upper left')

plt.subplot(335)
plt.title('z=3.5, y=3', fontsize='16')
plt.xlim(0,6)
plt.ylim(0,10)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.plot(realz35y3_ypol[:,0],realz35y3_ypol[:,1], label= 'ypol', color="#b4464b")
plt.plot(realz35y3_zpol[:,0],realz35y3_zpol[:,1], label= 'zpol', color="#4682b4")

plt.subplot(336)
plt.title('z=6.5, y=3', fontsize='16')
plt.xlim(0,6)
plt.ylim(0,10)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.plot(realz65y3_ypol[:,0],realz65y3_ypol[:,1], label= 'ypol', color="#b4464b")
plt.plot(realz65y3_zpol[:,0],realz65y3_zpol[:,1], label= 'zpol', color="#4682b4")
#plt.legend(fontsize="16")

plt.subplot(337)
plt.title('z=1.5, y=6', fontsize='16')
plt.xlim(0,6)
plt.ylim(0,10)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
plt.plot(realz15y6_ypol[:,0],realz15y6_ypol[:,1], label= 'ypol', color="#b4464b")
plt.plot(realz15y6_zpol[:,0],realz15y6_zpol[:,1], label= 'zpol', color="#4682b4")
plt.legend(fontsize="16", loc='upper left')

plt.subplot(338)
plt.title('z=3.5, y=6', fontsize='16')
plt.xlim(0,6)
plt.ylim(0,10)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(realz35y6_ypol[:,0],realz35y6_ypol[:,1], label= 'ypol', color="#b4464b")
plt.plot(realz35y6_zpol[:,0],realz35y6_zpol[:,1], label= 'zpol', color="#4682b4")

plt.subplot(339)
plt.title('z=6.5, y=6', fontsize='16')
plt.xlim(0,6)
plt.ylim(0,10)
plt.xticks(ticks=[1,2,3,4,5,6])
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(realz65y6_ypol[:,0],realz65y6_ypol[:,1], label= 'ypol', color="#b4464b")
plt.plot(realz65y6_zpol[:,0],realz65y6_zpol[:,1], label= 'zpol', color="#4682b4")

plt.show()

# %%
fid,axes = plt.subplots(2,3, figsize=(12,13), layout='tight')

plt.suptitle('Real Dielectric ($\epsilon_1$) at Z=6.5 and Y=8-13',fontsize='20')

real8y = np.loadtxt('z-6_y8/ypol/epsilon_real.out')
real8z =np.loadtxt('z-6_y8/zpol/epsilon_real.out')

real9y = np.loadtxt('z-6_y9/ypol/epsilon_real.out')
real9z =np.loadtxt('z-6_y9/zpol/epsilon_real.out')

real10y = np.loadtxt('z-6_y10/ypol/epsilon_real.out')
real10z =np.loadtxt('z-6_y10/zpol/epsilon_real.out')

real11y = np.loadtxt('z-6_y11/ypol/epsilon_real.out')
real11z =np.loadtxt('z-6_y11/zpol/epsilon_real.out')

real12y = np.loadtxt('z-6_y12/ypol/epsilon_real.out')
real12z =np.loadtxt('z-6_y12/zpol/epsilon_real.out')
                    
real13y = np.loadtxt('z-6_y13/ypol/epsilon_real.out')
real13z =np.loadtxt('z-6_y13/zpol/epsilon_real.out')

plt.subplot(2,3,1)
plt.title('y=8')
#plt.xlabel('Frequency $\omega$ (eV)')
plt.ylabel('$\epsilon (\omega) $')
plt.xlim(0,10)
plt.ylim(0,10)
plt.plot(real8y[:,0],real8y[:,1], label= 'ypol')
plt.plot(real8z[:,0],real8z[:,1], label= 'zpol')                    
                    
plt.legend()

plt.subplot(2,3,2)
plt.title('y=9')
plt.xlim(0,10)
plt.ylim(0,10)
plt.plot(real8y[:,0],real8y[:,1], label= 'ypol')
plt.plot(real8z[:,0],real8z[:,1], label= 'zpol') 
plt.legend()

plt.subplot(2,3,3)
plt.title('y=10')
plt.xlim(0,10)
plt.ylim(0,10)
plt.plot(real8y[:,0],real8y[:,1], label= 'ypol')
plt.plot(real8z[:,0],real8z[:,1], label= 'zpol') 
plt.legend()

plt.subplot(2,3,4)
plt.title('y=11')
plt.xlim(0,10)
plt.ylim(0,10)
plt.xlabel('Frequency $\omega$ (eV)')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.plot(real8y[:,0],real8y[:,1], label= 'ypol')
plt.plot(real8z[:,0],real8z[:,1], label= 'zpol') 
plt.legend()

plt.subplot(2,3,5)
plt.title('y=12')
plt.xlim(0,10)
plt.ylim(0,10)
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(real8y[:,0],real8y[:,1], label= 'ypol')
plt.plot(real8z[:,0],real8z[:,1], label= 'zpol') 
plt.legend()

plt.subplot(2,3,6)
plt.title('y=13')
plt.xlim(0,10)
plt.ylim(0,10)
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(real8y[:,0],real8y[:,1], label= 'ypol')
plt.plot(real8z[:,0],real8z[:,1], label= 'zpol') 
plt.legend()
