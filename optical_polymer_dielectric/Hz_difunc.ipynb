# %%
import matplotlib.pyplot as plt
import matplotlib.axes as ax
import seaborn
import numpy as np
import pandas as pd
from IPython import display
import math

# %%
conv=(2.4*10**(14))
print(conv)
# Out:
# 240000000000000.0

# %%
realz1y0_zpol = np.loadtxt('z1_y0/zpol/epsilon_real.out')
imagz1y0_zpol =np.loadtxt('z1_y0/zpol/epsilon_img.out')
realz1y0_xpol = np.loadtxt('z1_y0/xpol/epsilon_real.out')
imagz1y0_xpol =np.loadtxt('z1_y0/xpol/epsilon_img.out')
realz1y0_ypol = np.loadtxt('z1_y0/ypol/epsilon_real.out')
imagz1y0_ypol =np.loadtxt('z1_y0/ypol/epsilon_img.out')

realz15y0_zpol = np.loadtxt('z1.5_y0/zpol/epsilon_real.out')
imagz15y0_zpol =np.loadtxt('z1.5_y0/zpol/epsilon_img.out')
realz15y0_xpol = np.loadtxt('z1.5_y0/xpol/epsilon_real.out')
imagz15y0_xpol =np.loadtxt('z1.5_y0/xpol/epsilon_img.out')
realz15y0_ypol = np.loadtxt('z1.5_y0/ypol/epsilon_real.out')
imagz15y0_ypol =np.loadtxt('z1.5_y0/ypol/epsilon_img.out')

realz25y0_zpol = np.loadtxt('z2.5_y0/zpol/epsilon_real.out')
imagz25y0_zpol =np.loadtxt('z2.5_y0/zpol/epsilon_img.out')
realz25y0_xpol = np.loadtxt('z2.5_y0/xpol/epsilon_real.out')
imagz25y0_xpol =np.loadtxt('z2.5_y0/xpol/epsilon_img.out')
realz25y0_ypol = np.loadtxt('z2.5_y0/ypol/epsilon_real.out')
imagz25y0_ypol =np.loadtxt('z2.5_y0/ypol/epsilon_img.out')
                            
realz35y0_zpol = np.loadtxt('z3.5_y0/zpol/epsilon_real.out')
imagz35y0_zpol =np.loadtxt('z3.5_y0/zpol/epsilon_img.out')
#realz35y0_xpol = np.loadtxt('z3.5_y0/xpol/epsilon_real.out')
#imagz35y0_xpol =np.loadtxt('z3.5_y0/xpol/epsilon_img.out')
realz35y0_ypol = np.loadtxt('z3.5_y0/ypol/epsilon_real.out')
imagz35y0_ypol =np.loadtxt('z3.5_y0/ypol/epsilon_img.out')                            
             
realz45y0_zpol = np.loadtxt('z4.5_y0/zpol/epsilon_real.out')
imagz45y0_zpol =np.loadtxt('z4.5_y0/zpol/epsilon_img.out')
realz45y0_xpol = np.loadtxt('z4.5_y0/xpol/epsilon_real.out')
imagz45y0_xpol =np.loadtxt('z4.5_y0/xpol/epsilon_img.out')
realz45y0_ypol = np.loadtxt('z4.5_y0/ypol/epsilon_real.out')
imagz45y0_ypol =np.loadtxt('z4.5_y0/ypol/epsilon_img.out')                            
                            
realz55y0_zpol = np.loadtxt('z5.5_y0/zpol/epsilon_real.out')
imagz55y0_zpol =np.loadtxt('z5.5_y0/zpol/epsilon_img.out')
realz55y0_xpol = np.loadtxt('z5.5_y0/xpol/epsilon_real.out')
imagz55y0_xpol =np.loadtxt('z5.5_y0/xpol/epsilon_img.out')
realz55y0_ypol = np.loadtxt('z5.5_y0/ypol/epsilon_real.out')
imagz55y0_ypol =np.loadtxt('z5.5_y0/ypol/epsilon_img.out')   

realz65y0_zpol = np.loadtxt('z6.5_y0/zpol/epsilon_real.out')
imagz65y0_zpol =np.loadtxt('z6.5_y0/zpol/epsilon_img.out')
realz65y0_xpol = np.loadtxt('z6.5_y0/xpol/epsilon_real.out')
imagz65y0_xpol =np.loadtxt('z6.5_y0/xpol/epsilon_img.out')
realz65y0_ypol = np.loadtxt('z6.5_y0/ypol/epsilon_real.out')
imagz65y0_ypol =np.loadtxt('z6.5_y0/ypol/epsilon_img.out')

# %%
realz15y3_zpol = np.loadtxt('z1.5_y3/zpol/epsilon_real.out')
imagz15y3_zpol =np.loadtxt('z1.5_y3/zpol/epsilon_img.out')
realz15y3_ypol = np.loadtxt('z1.5_y3/ypol/epsilon_real.out')
imagz15y3_ypol =np.loadtxt('z1.5_y3/ypol/epsilon_img.out')
            
realz35y3_zpol = np.loadtxt('z3.5_y3/zpol/epsilon_real.out')
imagz35y3_zpol =np.loadtxt('z3.5_y3/zpol/epsilon_img.out')
realz35y3_ypol = np.loadtxt('z3.5_y3/ypol/epsilon_real.out')
imagz35y3_ypol =np.loadtxt('z3.5_y3/ypol/epsilon_img.out')                            

realz65y3_zpol = np.loadtxt('z6.5_y3/zpol/epsilon_real.out')
imagz65y3_zpol =np.loadtxt('z6.5_y3/zpol/epsilon_img.out')
realz65y3_ypol = np.loadtxt('z6.5_y3/ypol/epsilon_real.out')
imagz65y3_ypol =np.loadtxt('z6.5_y3/ypol/epsilon_img.out')

# %%
realz15y6_zpol = np.loadtxt('z1.5_y6/zpol/epsilon_real.out')
imagz15y6_zpol =np.loadtxt('z1.5_y6/zpol/epsilon_img.out')
realz15y6_ypol = np.loadtxt('z1.5_y6/ypol/epsilon_real.out')
imagz15y6_ypol =np.loadtxt('z1.5_y6/ypol/epsilon_img.out')
            
realz35y6_zpol = np.loadtxt('z3.5_y6/zpol/epsilon_real.out')
imagz35y6_zpol =np.loadtxt('z3.5_y6/zpol/epsilon_img.out')
realz35y6_ypol = np.loadtxt('z3.5_y6/ypol/epsilon_real.out')
imagz35y6_ypol =np.loadtxt('z3.5_y6/ypol/epsilon_img.out')                            

realz65y6_zpol = np.loadtxt('z6.5_y6/zpol/epsilon_real.out')
imagz65y6_zpol =np.loadtxt('z6.5_y6/zpol/epsilon_img.out')
realz65y6_ypol = np.loadtxt('z6.5_y6/ypol/epsilon_real.out')
imagz65y6_ypol =np.loadtxt('z6.5_y6/ypol/epsilon_img.out')

# %%
fig, axes= plt.subplots(nrows=2, ncols=3, layout='tight', figsize=(12,6) )
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

plt.suptitle('X-direction Polarization   Across Z-distances 1-6.5 at Y=0')

plt.subplot(2,3,1)
plt.title('z=1')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.xlim(0,(10**15))
#plt.ylim(0,8)
#plt.xticks(ticks=[1,2,3,4,5,6])

plt.plot(conv*realz1y0_xpol[:,0],realz1y0_xpol[:,1], label= 'Real')
plt.plot(conv*imagz1y0_xpol[:,0],imagz1y0_xpol[:,1], label= 'Imaginary')

plt.subplot(2,3,2)
plt.title('z=1.5')
plt.xlim(0,(10**15))
#plt.ylim(0,8)
#plt.xticks(ticks=[1,2,3,4,5,6])

plt.plot(conv*realz15y0_xpol[:,0],realz15y0_xpol[:,1], label= 'Real')
plt.plot(conv*imagz15y0_xpol[:,0],imagz15y0_xpol[:,1], label= 'Imaginary')

plt.subplot(2,3,3)
plt.title('z=2.5')
plt.xlim(0,(10**15))
#plt.ylim(0,8)
#plt.xticks(ticks=[1,2,3,4,5,6])
plt.plot(conv*realz25y0_xpol[:,0],realz25y0_xpol[:,1], label= 'Real')
plt.plot(conv*imagz25y0_xpol[:,0],imagz25y0_xpol[:,1], label= 'Imaginary')
plt.legend(fontsize="7")

plt.subplot(2,3,4)
plt.title('z=4.5')
plt.xlim(0,(10**15))
#plt.ylim(0,8)
#plt.xticks(ticks=[1,2,3,4,5,6])
plt.xlabel('Frequency $\omega$ (Hz)')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.plot(conv*realz45y0_xpol[:,0],realz45y0_xpol[:,1], label= 'Real')
plt.plot(conv*imagz45y0_xpol[:,0],imagz45y0_xpol[:,1], label= 'Imaginary')

plt.subplot(2,3,5)
plt.title('z=5.5')
plt.xlim(0,(10**15))
#plt.ylim(0,8)
#plt.xticks(ticks=[1,2,3,4,5,6])
plt.xlabel('Frequency $\omega$ (Hz)')
plt.plot(conv*realz55y0_xpol[:,0],realz55y0_xpol[:,1], label= 'Real')
plt.plot(conv*imagz55y0_xpol[:,0],imagz55y0_xpol[:,1], label= 'Imaginary')

plt.subplot(2,3,6)
plt.title('z=6.5')
plt.xlim(0,(10**15))
#plt.ylim(0,8)
#plt.xticks(ticks=[1,2,3,4,5,6])
plt.xlabel('Frequency $\omega$ (Hz)')
plt.plot(conv*realz65y0_xpol[:,0],realz65y0_xpol[:,1], label= 'Real')
plt.plot(conv*imagz65y0_xpol[:,0],imagz65y0_xpol[:,1], label= 'Imaginary')

plt.tight_layout(pad=1)
plt.show()

# %%
fig, axes= plt.subplots(nrows=2, ncols=3,  dpi=600, layout='tight')
##plt.xlim(-0.2,6)
##plt.ylim(-0.2,18)
##plt.xticks(ticks=[1,2,3,4,5,6])

plt.suptitle('Z-direction Polarization   Across Z-distances 1-6.5 at Y=0')  

plt.subplot(2,3,1)
plt.title('z=1')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
#plt.xlim(-0.2,6)
#plt.ylim(-0.2,18)
#plt.xticks(ticks=[1,2,3,4,5,6])
plt.plot(conv*realz1y0_zpol[:,0],realz1y0_zpol[:,1], label= 'Real')
plt.plot(conv*imagz1y0_zpol[:,0],imagz1y0_zpol[:,1], label= 'Imaginary')

plt.subplot(2,3,2)
plt.title('z=1.5')
#plt.xlim(-0.2,6)
#plt.ylim(-0.2,18)
#plt.xticks(ticks=[1,2,3,4,5,6])
plt.plot(conv*realz15y0_zpol[:,0],realz15y0_zpol[:,1], label= 'Real')
plt.plot(conv*imagz15y0_zpol[:,0],imagz15y0_zpol[:,1], label= 'Imaginary')

plt.subplot(2,3,3)
plt.title('z=2.5')
#plt.xlim(-0.2,6)
#plt.ylim(-0.2,18)
#plt.xticks(ticks=[1,2,3,4,5,6])
plt.plot(conv*realz25y0_zpol[:,0],realz25y0_zpol[:,1], label= 'Real')
plt.plot(conv*imagz25y0_zpol[:,0],imagz25y0_zpol[:,1], label= 'Imaginary')
plt.legend(fontsize="7")

plt.subplot(2,3,4)
plt.title('z=4.5')
#plt.xlim(-0.2,6)
#plt.ylim(-0.2,18)
#plt.xticks(ticks=[1,2,3,4,5,6])
plt.xlabel('Frequency $\omega$ (eV)')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.plot(conv*realz45y0_zpol[:,0],realz45y0_zpol[:,1], label= 'Real')
plt.plot(conv*imagz45y0_zpol[:,0],imagz45y0_zpol[:,1], label= 'Imaginary')

plt.subplot(2,3,5)
plt.title('z=5.5')
#plt.xlim(-0.2,6)
#plt.ylim(-0.2,18)
#plt.xticks(ticks=[1,2,3,4,5,6])
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(conv*realz55y0_zpol[:,0],realz55y0_zpol[:,1], label= 'Real')
plt.plot(conv*imagz55y0_zpol[:,0],imagz55y0_zpol[:,1], label= 'Imaginary')

plt.subplot(2,3,6)
plt.title('z=6.5')
#plt.xlim(-0.2,6)
#plt.ylim(-0.2,18)
#plt.xticks(ticks=[1,2,3,4,5,6])
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(conv*realz65y0_zpol[:,0],realz65y0_zpol[:,1], label= 'Real')
plt.plot(conv*imagz65y0_zpol[:,0],imagz65y0_zpol[:,1], label= 'Imaginary')

plt.show()

# %%
plt.figure( dpi=600, layout='tight')
plt.subplots(nrows=2, ncols=3, sharex='all', sharey='all')
##plt.xlim(0,6)
#plt.ylim(0,8)

plt.suptitle('Z-direction Polarization  Across Z-distances 1-6.5 at Y=0')

plt.subplot(2,3,1)
plt.title('z=1')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.plot(conv*realz15y0_ypol[:,0],realz1y0_ypol[:,1], label= 'Real')
plt.plot(conv*imagz1y0_ypol[:,0],imagz1y0_ypol[:,1], label= 'Imaginary')

plt.subplot(2,3,2)
plt.title('z=1.5')
plt.plot(conv*realz15y0_ypol[:,0],realz15y0_ypol[:,1], label= 'Real')
plt.plot(conv*imagz15y0_ypol[:,0],imagz15y0_ypol[:,1], label= 'Imaginary')

plt.subplot(2,3,3)
plt.title('z=2.5')
plt.plot(conv*realz25y0_ypol[:,0],realz25y0_ypol[:,1], label= 'Real')
plt.plot(conv*imagz25y0_ypol[:,0],imagz25y0_ypol[:,1], label= 'Imaginary')
plt.legend(fontsize="7")

plt.subplot(2,3,4)
plt.title('z=4.5')
plt.xlabel('Frequency $\omega$ (eV)')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.plot(conv*realz45y0_ypol[:,0],realz45y0_ypol[:,1], label= 'Real')
plt.plot(conv*imagz45y0_ypol[:,0],imagz45y0_ypol[:,1], label= 'Imaginary')

plt.subplot(2,3,5)
plt.title('z=5.5')
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(conv*realz55y0_ypol[:,0],realz55y0_ypol[:,1], label= 'Real')
plt.plot(conv*imagz55y0_ypol[:,0],imagz55y0_ypol[:,1], label= 'Imaginary')

plt.subplot(2,3,6)
plt.title('z=6.5')
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(conv*realz65y0_ypol[:,0],realz65y0_ypol[:,1], label= 'Real')
plt.plot(conv*imagz65y0_ypol[:,0],imagz65y0_ypol[:,1], label= 'Imaginary')

plt.show()

# %%
plt.subplots(2,3, sharex='all', sharey='all', figsize=(10,8), layout='tight')
##plt.xlim(0,6)
#plt.ylim(0,8)

plt.suptitle('Z-direction Polarization  Across Z-distances 1-6.5 at Y=3',fontsize='20')

plt.subplot(231)
plt.title('z=1.5', fontsize='16')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
plt.plot(conv*realz15y3_zpol[:,0],realz15y3_zpol[:,1], label= '$\epsilon_1$')
plt.plot(conv*imagz15y3_zpol[:,0],imagz15y3_zpol[:,1], label= '$\epsilon_2$')
plt.legend(fontsize="12", loc='upper left')

plt.subplot(232)
plt.title('z=3.5', fontsize='16')
plt.plot(conv*realz35y3_zpol[:,0],realz35y3_zpol[:,1], label= '$\epsilon_1$')
plt.plot(conv*imagz35y3_zpol[:,0],imagz35y3_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(233)
plt.title('z=6.5', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(conv*realz65y3_zpol[:,0],realz65y3_zpol[:,1], label= '$\epsilon_1$')
plt.plot(conv*imagz65y3_zpol[:,0],imagz65y3_zpol[:,1], label= '$\epsilon_2$')


plt.suptitle('Z-direction Polarization  Across Z-distances 1-6.5 at Y=6')

plt.subplot(234)
plt.title('z=1.5', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
plt.plot(conv*realz15y6_zpol[:,0],realz15y6_zpol[:,1], label= '$\epsilon_1$')
plt.plot(conv*imagz15y6_zpol[:,0],imagz15y6_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(235)
plt.title('z=3.5', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(conv*realz35y6_zpol[:,0],realz35y6_zpol[:,1], label= '$\epsilon_1$')
plt.plot(conv*imagz35y6_zpol[:,0],imagz35y6_zpol[:,1], label= '$\epsilon_2$')

plt.subplot(236)
plt.title('z=6.5', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(conv*realz65y6_zpol[:,0],realz65y6_zpol[:,1], label= '$\epsilon_1$')
plt.plot(conv*imagz65y6_zpol[:,0],imagz65y6_zpol[:,1], label= '$\epsilon_2$')
#plt.legend(fontsize="12", loc='upper left')

plt.show()

# %%
fig, ax = plt.subplots(1,3, sharex='all', sharey='all')
##plt.xlim(0,6)
#plt.ylim(0,8)

plt.suptitle('Z-direction Polarization  Across Z-distances 1-6.5 at Y=6')

plt.subplot(1,3,1)
plt.title('z=1.5')
plt.xlabel('Frequency $\omega$ (eV)')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.plot(conv*realz15y6_zpol[:,0],realz15y6_zpol[:,1], label= 'Real')
plt.plot(conv*imagz15y6_zpol[:,0],imagz15y6_zpol[:,1], label= 'Imaginary')

plt.subplot(1,3,2)
plt.title('z=3.5')
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(conv*realz35y6_zpol[:,0],realz35y6_zpol[:,1], label= 'Real')
plt.plot(conv*imagz35y6_zpol[:,0],imagz35y6_zpol[:,1], label= 'Imaginary')

plt.subplot(1,3,3)
plt.title('z=6.5')
plt.xlabel('Frequency $\omega$ (eV)')
plt.plot(conv*realz65y6_zpol[:,0],realz65y6_zpol[:,1], label= 'Real')
plt.plot(conv*imagz65y6_zpol[:,0],imagz65y6_zpol[:,1], label= 'Imaginary')
plt.legend(fontsize="7")

plt.show()

# %%
plt.subplots(3,3, sharex='all', sharey='all', figsize=(12,13), layout='tight')
##plt.xlim(0,6)
#plt.ylim(0,8)

plt.suptitle('Z-direction Polarization $\epsilon_2$',fontsize='20')

plt.subplot(331)
plt.title('z=1.5, y=0', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
#plt.plot(conv*realz15y0_zpol[:,0],realz15y0_zpol[:,1], label= 'Real')
plt.plot(conv*imagz15y0_zpol[:,0],imagz15y0_zpol[:,1], label= 'Imaginary')

plt.subplot(332)
plt.title('z=3.5, y=0', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(conv*realz35y0_zpol[:,0],realz35y0_zpol[:,1], label= 'Real')
plt.plot(conv*imagz35y0_zpol[:,0],imagz35y0_zpol[:,1], label= 'Imaginary')

plt.subplot(333)
plt.title('z=6.5, y=0', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(conv*realz65y0_zpol[:,0],realz65y0_zpol[:,1], label= 'Real')
plt.plot(conv*imagz65y0_zpol[:,0],imagz65y0_zpol[:,1], label= 'Imaginary')
plt.legend(fontsize="12")


plt.subplot(334)
plt.title('z=1.5, y=3', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
#plt.plot(conv*realz15y3_zpol[:,0],realz15y3_zpol[:,1], label= 'Real')
plt.plot(conv*imagz15y3_zpol[:,0],imagz15y3_zpol[:,1], label= 'Imaginary')

plt.subplot(335)
plt.title('z=3.5, y=3', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(conv*realz35y3_zpol[:,0],realz35y3_zpol[:,1], label= 'Real')
plt.plot(conv*imagz35y3_zpol[:,0],imagz35y3_zpol[:,1], label= 'Imaginary')

plt.subplot(336)
plt.title('z=6.5, y=3', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(conv*realz65y3_zpol[:,0],realz65y3_zpol[:,1], label= 'Real')
plt.plot(conv*imagz65y3_zpol[:,0],imagz65y3_zpol[:,1], label= 'Imaginary')
plt.legend(fontsize="12")


plt.subplot(337)
plt.title('z=1.5, y=6', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
#plt.plot(conv*realz15y6_zpol[:,0],realz15y6_zpol[:,1], label= 'Real')
plt.plot(conv*imagz15y6_zpol[:,0],imagz15y6_zpol[:,1], label= 'Imaginary')

plt.subplot(338)
plt.title('z=3.5, y=6', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(conv*realz35y6_zpol[:,0],realz35y6_zpol[:,1], label= 'Real')
plt.plot(conv*imagz35y6_zpol[:,0],imagz35y6_zpol[:,1], label= 'Imaginary')

plt.subplot(339)
plt.title('z=6.5, y=6', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
#plt.plot(conv*realz65y6_zpol[:,0],realz65y6_zpol[:,1], label= 'Real')
plt.plot(conv*imagz65y6_zpol[:,0],imagz65y6_zpol[:,1], label= 'Imaginary')
plt.legend(fontsize="12")

plt.show()

# %%
plt.subplots(3,3, sharex='all', sharey='all', figsize=(12,13), layout='tight')
##plt.xlim(0,100)
#plt.ylim(0,5)

plt.suptitle('Y-direction Polarization',fontsize='20')

plt.subplot(331)
plt.title('z=1.5, y=0', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
plt.plot(conv*realz15y0_ypol[:,0],realz15y0_ypol[:,1], label= 'Real')
plt.plot(conv*imagz15y0_ypol[:,0],imagz15y0_ypol[:,1], label= 'Imaginary')

plt.subplot(332)
plt.title('z=3.5, y=0', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(conv*realz35y0_ypol[:,0],realz35y0_ypol[:,1], label= 'Real')
plt.plot(conv*imagz35y0_ypol[:,0],imagz35y0_ypol[:,1], label= 'Imaginary')

plt.subplot(333)
plt.title('z=6.5, y=0', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(conv*realz65y0_ypol[:,0],realz65y0_ypol[:,1], label= 'Real')
plt.plot(conv*imagz65y0_ypol[:,0],imagz65y0_ypol[:,1], label= 'Imaginary')
plt.legend(fontsize="12")


plt.subplot(334)
plt.title('z=1.5, y=3', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
plt.plot(conv*realz15y3_ypol[:,0],realz15y3_ypol[:,1], label= 'Real')
plt.plot(conv*imagz15y3_ypol[:,0],imagz15y3_ypol[:,1], label= 'Imaginary')

plt.subplot(335)
plt.title('z=3.5, y=3', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(conv*realz35y3_ypol[:,0],realz35y3_ypol[:,1], label= 'Real')
plt.plot(conv*imagz35y3_ypol[:,0],imagz35y3_ypol[:,1], label= 'Imaginary')

plt.subplot(336)
plt.title('z=6.5, y=3', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(conv*realz65y3_ypol[:,0],realz65y3_ypol[:,1], label= 'Real')
plt.plot(conv*imagz65y3_ypol[:,0],imagz65y3_ypol[:,1], label= 'Imaginary')
plt.legend(fontsize="12")


plt.subplot(337)
plt.title('z=1.5, y=6', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.ylabel('Dielectric Function $\epsilon (\omega) $', fontsize='14')
plt.plot(conv*realz15y6_ypol[:,0],realz15y6_ypol[:,1], label= 'Real')
plt.plot(conv*imagz15y6_ypol[:,0],imagz15y6_ypol[:,1], label= 'Imaginary')

plt.subplot(338)
plt.title('z=3.5, y=6', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(conv*realz35y6_ypol[:,0],realz35y6_ypol[:,1], label= 'Real')
plt.plot(conv*imagz35y6_ypol[:,0],imagz35y6_ypol[:,1], label= 'Imaginary')

plt.subplot(339)
plt.title('z=6.5, y=6', fontsize='16')
plt.xlabel('Frequency $\omega$ (eV)', fontsize='14')
plt.plot(conv*realz65y6_ypol[:,0],realz65y6_ypol[:,1], label= 'Real')
plt.plot(conv*imagz65y6_ypol[:,0],imagz65y6_ypol[:,1], label= 'Imaginary')
plt.legend(fontsize="12")

plt.show()

# %%
fig, axes= plt.subplots(nrows=2, ncols=3, figsize=(12,8), layout='tight')


plt.suptitle('X-direction Polarization   Across Z-distances 1-6.5 at Y=0')

plt.subplot(2,3,1)
plt.title('z=1')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.xlim(0,(10**15))
plt.plot(conv*realz1y0_xpol[:,0],realz1y0_xpol[:,1], label= '$\epsilon_1$', color='blue',linestyle = 'dashed')
plt.plot(conv*imagz1y0_xpol[:,0],imagz1y0_xpol[:,1], label= '$\epsilon_2$', color='orange',linewidth='2')
plt.legend(fontsize="12", loc='upper left')


plt.subplot(2,3,2)
plt.title('z=1.5')
plt.xlim(0,(10**15))
plt.plot(conv*realz15y0_xpol[:,0],realz15y0_xpol[:,1], label= '$\epsilon_1$', color='blue',linestyle = 'dashed')
plt.plot(conv*imagz15y0_xpol[:,0],imagz15y0_xpol[:,1], label= '$\epsilon_2$', color='orange',linewidth='2')

plt.subplot(2,3,3)
plt.title('z=2.5')
plt.xlim(0,(10**15))
#plt.ylim(0,8)
plt.plot(conv*realz25y0_xpol[:,0],realz25y0_xpol[:,1], label= '$\epsilon_1$', color='blue',linestyle = 'dashed')
plt.plot(conv*imagz25y0_xpol[:,0],imagz25y0_xpol[:,1], label= '$\epsilon_2$', color='orange',linewidth='2')

plt.subplot(2,3,4)
plt.title('z=4.5')
plt.xlim(0,(10**15))
#plt.ylim(0,8)
plt.xlabel('Frequency $\omega$ ($10^{15}$) Hz')
plt.ylabel('Dielectric Function $\epsilon (\omega) $')
plt.plot(conv*realz45y0_xpol[:,0],realz45y0_xpol[:,1], label= '$\epsilon_1$', color='blue',linestyle = 'dashed')
plt.plot(conv*imagz45y0_xpol[:,0],imagz45y0_xpol[:,1], label= '$\epsilon_2$', color='orange',linewidth='2')

plt.subplot(2,3,5)
plt.title('z=5.5')
plt.xlim(0,(10**15))
#plt.ylim(0,8)
plt.xlabel('Frequency $\omega$ ($10^{15}$) Hz')
plt.plot(conv*realz55y0_xpol[:,0],realz55y0_xpol[:,1], label= '$\epsilon_1$', color='blue',linestyle = 'dashed')
plt.plot(conv*imagz55y0_xpol[:,0],imagz55y0_xpol[:,1], label= '$\epsilon_2$', color='orange',linewidth='2')

plt.subplot(2,3,6)
plt.title('z=6.5')
plt.xlim(0,(10**15))
plt.xlabel('Frequency $\omega$ ($10^{15}$) Hz')
plt.plot(conv*realz65y0_xpol[:,0],realz65y0_xpol[:,1], label= '$\epsilon_1$', color = "blue",linestyle = 'dashed')
plt.plot(conv*imagz65y0_xpol[:,0],imagz65y0_xpol[:,1], label= '$\epsilon_2$', color='orange',linewidth='2')

plt.tight_layout(pad=1)
